# %%
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity
import torch
import numpy as np
import json
from tqdm import tqdm
import pandas as pd

# %%
tokenizer = BertTokenizer.from_pretrained('dmis-lab/biobert-base-cased-v1.2')
model = BertModel.from_pretrained('dmis-lab/biobert-base-cased-v1.2')

# %%
with open('extracted_symptoms_list.json','r') as extract_file:
    extracted_symptoms_list = json.load(extract_file)
    
with open('standard_symptoms_list.json','r') as standard_file:
    standard_symptoms_list = json.load(standard_file)
    
with open('top_100_list.json','r') as top:
    top_100 = json.load(top)
    
with open('ext_top.json','r') as top_ext:
    ext_top = json.load(top_ext)

# %%
len(ext_top)
# Out:
# 1000

# %%
len(top_100)
# Out:
# 100

# %%
100*(len(set(extracted_symptoms_list)))
# Out:
# 1914200

# %%
path = "dataset/"

# %%
pd.set_option('display.max_columns',None)

# %%
vax_vaers_data = pd.read_csv("VAX_VAERS_DATA.csv")

# %%
symptoms_in_reports = []
for i in vax_vaers_data["SYMPTOM_TEXT"].dropna():
    symptoms_in_reports.append(i)

# %%
symptoms_frequency = dict()
for i in extracted_symptoms_list:
    symptoms_frequency[i] = sum(entry.count(i) for entry in symptoms_in_reports)

# %%
symptoms_frequency

# %%
ext_top = dict(sorted(symptoms_frequency.items(), key=lambda x: x[1], reverse=True)[:1000])

# %%
ext_top

# %%
import json
with open("ext_top.json",'w') as op_file:
    json.dump(list(ext_top),op_file)

# %%
import json
with open("symptoms_frequency.json",'w') as op_file:
    json.dump(symptoms_frequency,op_file)

# %%
similarity_scores = dict()
for symp in tqdm(set(ext_top)):
    scores = dict()
    for std_symp in top_100:
        std_symp_tokens = tokenizer(std_symp, return_tensors='pt')
        symp_tokens = tokenizer(symp, return_tensors='pt')

        with torch.no_grad():
            std_symp_emb = model(**std_symp_tokens).last_hidden_state.mean(dim=1)
            symp_emb = model(**symp_tokens).last_hidden_state.mean(dim=1)

        std_symp_emb = std_symp_emb.detach().numpy()
        symp_emb = symp_emb.detach().numpy()

        scores[std_symp] = cosine_similarity([np.ravel(std_symp_emb)],[np.ravel(symp_emb)])[0][0]
        
    max_key, max_val = max(scores.items(), key= lambda x: x[1])
    similarity_scores[symp] = [max_key, max_val]
#     break
# Out:
# 100%|██████████| 1000/1000 [3:38:45<00:00, 13.13s/it]

# %%
import csv
csv_file = 'similarity_scores.csv'

# Specify the CSV file name
csv_file = 'similarity_scores.csv'

# Reshape the dictionary into a list of tuples (key, value)
data = [(key, value) for key, value in similarity_scores.items()]

# Writing the reshaped data to a CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    
    # Write header
    writer.writerow(['Key', 'Value'])
    
    # Write data
    writer.writerows(data)

# %%
similarity_scores
# Out:
# {'stool': ['Swelling', 0.9072527],
#  'lightheadedness': ['Dizziness', 0.9160143],
#  'fainted': ['Vomiting', 0.8686165],
#  'itchiness': ['Pyrexia', 0.8744232],
#  'MYALGIA': ['Myalgia', 1.0000002],
#  'Swollen': ['Swelling', 0.9506608],
#  'flu like symptom': ['Pyrexia', 0.82842076],
#  'CKD': ['SARS-CoV-2 test', 0.82007635],
#  'pericarditis': ['Pericarditis', 1.0],
#  'an infection': ['Infection', 0.8943497],
#  'these symptoms': ['Tenderness', 0.87117016],
#  'PYREXIA (fever)': ['Pyrexia', 0.9441159],
#  'Throat': ['Cough', 0.9340446],
#  'tingling sensation': ['Burning sensation', 0.9725992],
#  'breakthrough': ['Swelling', 0.92750686],
#  'TENDERNESS': ['Tenderness', 0.99999994],
#  'sick': ['Seizure', 0.938822],
#  'a side effect': ['Pyrexia', 0.86037886],
#  'anaphylactic': ['Tachycardia', 0.8214239],
#  'DISCOMFORT': ['Discomfort', 1.0],
#  'covid': ['COVID-19', 0.85596645],
#  'HEADACHE': ['Headache', 1.0],
#  'concurrent conditions': ['Drug ineffective', 0.8543272],
#  'cramping': ['Pyrexia', 0.8581922],
#  'nervous': ['Seizure', 0.9446919],
#  'MI': ['Scar', 0.8629454],
#  'Painful': ['Discomfort', 0.93042517],
#  'lymphadenopathy': ['Pericarditis', 0.86762166],
#  'temperature excursion': ['Body temperature', 0.8742123],
#  'swollen lymph node': ['Pericarditis', 0.8397387],
#  'asthma': ['Asthma', 1.0],
#  'ITCH': ['Tenderness', 0.8744189],
#  'tremor': ['Tremor', 0.99999994],
#  'brain fog': ['Brain fog', 0.9999999],
#  'shortness of breath': ['Dizziness', 0.8203939],
#  'D.': ['Vitamin D', 0.8545675],
#  'clots': ['Thrombosis', 0.87412906],
#  'Sleep': ['Anxiety', 0.8821017],
#  'CAD': ['Vitamin D', 0.8228883],
#  'episode': ['Illness', 0.9085543],
#  'FATIGUE (fatigue': ['Tenderness', 0.8509509],
#  'sweats': ['Chills', 0.9331792],
#  'problem': ['Headache', 0.8786601],
#  'ABDOMINAL PAIN': ['Abdominal pain', 1.0000002],
#  'Shortness of breat': ['Interchange of vaccine products', 0.87250644],
#  'sweaty': ['Seizure', 0.93686414],
#  'HA': ['Swelling', 0.81766707],
#  'sweat': ['Anxiety', 0.8912532],
#  'stress': ['Stress', 0.9999999],
#  'Cold': ['Anxiety', 0.8822789],
#  'Swollen lymph nodes': ['Pericarditis', 0.8309663],
#  'CP': ['COVID-19', 0.81088144],
#  'TINNITUS': ['Tinnitus', 1.0000001],
#  'scared': ['Seizure', 0.886051],
#  'itchy': ['Tenderness', 0.86370736],
#  'symptoms': ['Anxiety', 0.9378116],
#  'Hypothyroidism': ['Hypothyroidism', 0.9999996],
#  'Sore': ['Scar', 0.9173199],
#  'COVID positive': ['COVID-19', 0.8817861],
#  'RR': ['Rash', 0.78562695],
#  'body aches)': ['Chills', 0.8697804],
#  'MIGRAINE': ['Migraine', 1.0],
#  'hypoxic': ['Dehydration', 0.84875685],
#  'shaking': ['Seizure', 0.9108316],
#  'BNT162B2': ['SARS-CoV-2 test', 0.8446757],
#  'thirsty': ['Vomiting', 0.8690901],
#  'itching': ['Tenderness', 0.8921311],
#  'FATIGUE (Fatigue)': ['Tenderness', 0.8631501],
#  'MYALGIA (body aches': ['Fibromyalgia', 0.8929507],
#  'embolism': ['Thrombosis', 0.90214634],
#  'blurred': ['Swelling', 0.91121835],
#  'temperature': ['Anxiety', 0.85971653],
#  'anxious': ['Seizure', 0.93841213],
#  'elevation': ['Anxiety', 0.91264844],
#  'Shingles': ['Brain fog', 0.8477738],
#  'headaches': ['Back pain', 0.8869767],
#  'stiffness': ['Tenderness', 0.90349066],
#  'PRURITUS (Itching': ['Pruritus', 0.9289702],
#  'body ache': ['Body temperature', 0.89013463],
#  'Soreness': ['Tenderness', 0.95982194],
#  'flush': ['Scar', 0.89465666],
#  'tingling': ['Seizure', 0.920629],
#  'scab': ['SARS-CoV-2 test', 0.84149945],
#  'conscious': ['Anxiety', 0.8845827],
#  'warm to touch': ['Feeling cold', 0.8517087],
#  'a migraine': ['Migraine', 0.95337516],
#  'Ache': ['Seizure', 0.9457807],
#  'runny nose': ['Pyrexia', 0.83112097],
#  'sores': ['Chills', 0.877996],
#  'hearing loss': ['Back pain', 0.8718177],
#  'taste': ['Anxiety', 0.905451],
#  'flu-like': ['Pyrexia', 0.840442],
#  'Diarrhea': ['Dizziness', 0.87067735],
#  'Diabetes': ['Illness', 0.8947775],
#  'weird': ['Scar', 0.8708434],
#  'loss of appetite': ['Vertigo', 0.8601463],
#  'PAIN': ['Pain', 1.0],
#  'chill': ['Anxiety', 0.912954],
#  'Discomfort': ['Discomfort', 1.0],
#  'OROPHARYNGEAL PAIN': ['Fibromyalgia', 0.8303725],
#  'bad headache': ['Vomiting', 0.87569296],
#  'disease': ['Illness', 0.91918606],
#  'cramps': ['Pyrexia', 0.8619281],
#  'Body aches)': ['Chills', 0.8697804],
#  'burning': ['Swelling', 0.91586185],
#  'Tingling': ['Seizure', 0.920629],
#  'neuropathy': ['Pyrexia', 0.87798285],
#  'Itch': ['Tenderness', 0.8744189],
#  'complaints': ['Discomfort', 0.9338677],
#  'severe': ['Illness', 0.890327],
#  'VAERS': ['COVID-19 pneumonia', 0.85726833],
#  'weak)': ['Anxiety', 0.8608813],
#  'generalized weakness': ['Tenderness', 0.866828],
#  'DVT': ['SARS-CoV-2 test', 0.8170599],
#  'Arthritis': ['Arthritis', 0.9999999],
#  'VACCINATION SITE RASH': ['Vaccination site pain', 0.96616906],
#  'Vertigo': ['Vertigo', 1.0000002],
#  'DIARRHOEA': ["Crohn's disease", 0.8601141],
#  'Symptom': ['Injection site pain', 0.8105614],
#  'rashes': ['Rash', 0.95319396],
#  'needles': ['Seizure', 0.9127811],
#  'Anxiety': ['Anxiety', 1.0],
#  'joint aches': ['Abdominal pain', 0.89923143],
#  'injection site': ['Injection site pain', 0.91822743],
#  'sleep': ['Anxiety', 0.8821017],
#  'hot flash': ['Blood test', 0.84801257],
#  'achiness': ['Pyrexia', 0.8858552],
#  'INJECTION SITE PAIN': ['Injection site pain', 1.0],
#  'peeling': ['Blister', 0.8645067],
#  'NASAL CONGESTION': ['Abdominal pain', 0.9102902],
#  'right arm': ['Abdominal pain', 0.82339966],
#  'The rash': ['Rash', 0.91543055],
#  'dots': ['Anxiety', 0.8622147],
#  'shoulder and neck': ['Neck pain', 0.8851857],
#  'pains': ['Seizure', 0.93397593],
#  'dementia': ['Multiple sclerosis', 0.85025626],
#  'burning sensation': ['Burning sensation', 1.0000002],
#  'tinnit': ['Tinnitus', 0.93181646],
#  'depression': ['Depression', 0.9999999],
#  'RA': ['COVID-19', 0.8134203],
#  'very sore': ['Tenderness', 0.849239],
#  'underarm': ['Brain fog', 0.8483942],
#  'Injection site': ['Injection site pain', 0.91822743],
#  'MYALGIA (muscle pain': ['Myalgia', 0.9160911],
#  'low fever': ['Sepsis', 0.8975468],
#  'blood clot': ['Thrombosis', 0.8888079],
#  'very painful': ['Abdominal pain', 0.88659483],
#  'medical condition': ['Drug ineffective', 0.8917843],
#  'lightheaded': ['Tenderness', 0.8774801],
#  'fluid': ['Swelling', 0.87579954],
#  'rapid heart rate': ['Heart rate', 0.95091736],
#  'lymph nodes': ['Tenderness', 0.826954],
#  'PAIN IN EXTREMITY (Sore arm)': ['Injection site pain', 0.8485743],
#  'dry cough': ['Abdominal pain', 0.89206296],
#  'Fainting': ['Vomiting', 0.9136364],
#  'swelling': ['Swelling', 0.9999998],
#  'nasal congestion': ['Abdominal pain', 0.9102902],
#  'SYMPTOMS': ['Anxiety', 0.9378116],
#  'Fever': ['Illness', 0.9041469],
#  'gas': ['Scar', 0.8758775],
#  'horrible': ['Seizure', 0.94291794],
#  'breast cancer': ['Abdominal pain', 0.86370575],
#  'blue': ['Swelling', 0.8385087],
#  'site soreness': ['Injection site pain', 0.9098638],
#  'febrile': ['Vertigo', 0.84705424],
#  'ill': ['Seizure', 0.9268365],
#  'HEADACHE (headache)': ['Pyrexia', 0.8633002],
#  'Known allergies': ['Allergy to vaccine', 0.9256422],
#  'COVID-19 infection': ['COVID-19 pneumonia', 0.9738523],
#  'the symptom': ['Blister', 0.8176633],
#  'DRUG INEFFECTIVE': ['Drug ineffective', 1.0],
#  'firm': ['Scar', 0.86599624],
#  'tachy': ['Tachycardia', 0.8592266],
#  'gout': ['Sepsis', 0.8698249],
#  'NDC': ['COVID-19', 0.79966915],
#  'dizziness': ['Dizziness', 1.0],
#  'Body aches': ['Abdominal pain', 0.895549],
#  'right eye': ['Abdominal pain', 0.82728726],
#  'coma': ['Anxiety', 0.88728523],
#  'the side effect': ['Injection site pain', 0.843823],
#  'skin': ['Scar', 0.90495175],
#  'sharp pain': ['Abdominal pain', 0.9287993],
#  'PAIN (Pain': ['Injection site pain', 0.89718777],
#  'same symptom': ['Blister', 0.815992],
#  'bruised': ['Seizure', 0.94006526],
#  'LOC': ['Blood test', 0.7855835],
#  '(Pain': ['Discomfort', 0.85516304],
#  'bumps': ['Scar', 0.9243728],
#  'BAC': ['Vomiting', 0.83540463],
#  'COVID-19 vaccination': ['COVID-19 immunisation', 0.9638569],
#  'pulmonary emboli': ['Thrombosis', 0.9014691],
#  'ASTHENIA': ['Pyrexia', 0.8861942],
#  'body': ['Weight', 0.8846204],
#  'heart palpitation': ['Palpitations', 0.9599196],
#  'RASH (rash': ['Rash', 0.91671556],
#  'V': ['Vitamin D', 0.76245666],
#  'very hot': ['Body temperature', 0.85113364],
#  'Weakness': ['Anxiety', 0.9275498],
#  'other symptoms': ['Abdominal pain', 0.88609296],
#  'flu': ['Swelling', 0.88419783],
#  'blood': ['Death', 0.8509455],
#  'Drug allergy': ['Allergy to vaccine', 0.93125296],
#  'joint pain': ['Neck pain', 0.94620824],
#  'arthritis': ['Arthritis', 0.9999999],
#  'cramp': ['Blister', 0.85951006],
#  'AEs': ['Pyrexia', 0.8298639],
#  'side effects': ['Abdominal pain', 0.84612465],
#  '1 temperature excursion': ['Lethargy', 0.838562],
#  'ae': ['Pyrexia', 0.8324957],
#  'very tired': ['Feeling cold', 0.8501329],
#  'tachycardia': ['Tachycardia', 1.0000001],
#  'the skin': ['Tenderness', 0.85780984],
#  'Hypothyroid': ['Hypothyroidism', 0.9616902],
#  'INSOMNIA': ['Insomnia', 1.0],
#  'the reaction': ['Blood test', 0.84442276],
#  'Pressure': ['Anxiety', 0.89515734],
#  'AF': ['COVID-19', 0.82112974],
#  's palsy': ["Bell's palsy", 0.9347085],
#  'Hot flashes': ['Abdominal pain', 0.896962],
#  'SWELLING': ['Swelling', 0.9999998],
#  'Hive': ['Pneumonia', 0.82596505],
#  'VACCINATION COMPLICATION': ['Vaccination failure', 0.96082336],
#  'Stroke': ['Illness', 0.86876637],
#  'VACCINATION SITE MASS': ['Vaccination site swelling', 0.98197156],
#  'itch': ['Tenderness', 0.8744189],
#  'cyst': ['Blister', 0.86088204],
#  'Hypertension': ['Hypertension', 1.0],
#  'covid-19 infection': ['COVID-19 pneumonia', 0.9738523],
#  'rash': ['Rash', 1.0000002],
#  'sore arm': ['Neck pain', 0.86036223],
#  'elevated': ['Discomfort', 0.89789003],
#  'fall': ['Fall', 1.0],
#  'hands': ['Seizure', 0.8904767],
#  'very itchy': ['Feeling cold', 0.85270846],
#  'pregnancy': ['Pregnancy', 1.0000001],
#  'any temperature excursions': ['Body temperature', 0.8589901],
#  'Aches': ['Chills', 0.9098122],
#  'heart failure': ['Chest pain', 0.8887149],
#  'fever': ['Illness', 0.9041469],
#  'her symptom': ['Pyrexia', 0.8091016],
#  'complications': ['Discomfort', 0.9265379],
#  'PYREXIA (Fever)': ['Pyrexia', 0.9441159],
#  'myalgias': ['Myalgia', 0.9710415],
#  'apnea': ['Pyrexia', 0.88470197],
#  'panic attack': ['Abdominal pain', 0.878309],
#  'Death': ['Death', 0.9999999],
#  'pain in left arm': ['Injection site pain', 0.8694074],
#  'dry': ['Mass', 0.85813534],
#  'muscle soreness': ['Tenderness', 0.9274126],
#  'irritated': ['Discomfort', 0.90397775],
#  'menstrual cycle': ['Constipation', 0.7970867],
#  'feverish': ['Rash', 0.9006874],
#  'TEMPERATURE EXCURSION': ['Body temperature', 0.8742123],
#  'pneumonia': ['Pneumonia', 1.0],
#  'pale': ['Scar', 0.8774717],
#  'Numbness': ['Tenderness', 0.9600624],
#  'BODY ACHES': ['Abdominal pain', 0.895549],
#  'VACCINATION SITE PRURITUS': ['Vaccination site pain', 0.93749726],
#  'AE': ['Pyrexia', 0.8324957],
#  'high cholesterol': ['Dehydration', 0.80888414],
#  'COVID-19 virus': ['COVID-19 pneumonia', 0.9558872],
#  'TEMPERATURE EXCURSION ISSUE': ['Pyrexia', 0.846586],
#  'aggravated': ['Pyrexia', 0.8008836],
#  'nerve pain': ['Abdominal pain', 0.93389225],
#  'temp': ['Pyrexia', 0.8185561],
#  'site pain': ['Injection site pain', 0.94188434],
#  'SARS': ['SARS-CoV-2 test', 0.83593315],
#  'tremors': ['Tremor', 0.9801071],
#  'aching': ['Seizure', 0.93358743],
#  'ERYTHEMA (redness': ['Erythema', 0.93578815],
#  'FATIGUE (tired': ['Tenderness', 0.84339345],
#  'faint': ['Seizure', 0.87902486],
#  'lot of pain': ['Injection site pain', 0.90454835],
#  'TIA': ['Pneumonia', 0.82946956],
#  'suspected clinical vaccination failure': ['Vaccination failure', 0.9531349],
#  'ACCIDENTAL UNDERDOSE': ['Interchange of vaccine products', 0.8316547],
#  'a cold': ['Feeling cold', 0.8907758],
#  'sequelae': ['Illness', 0.8755758],
#  'purple': ['Swelling', 0.8645222],
#  'slight fever': ['Tenderness', 0.88592505],
#  'anemia': ['Sepsis', 0.8807833],
#  'chest pains': ['Chest pain', 0.9597068],
#  'body rash': ['Rash', 0.94286263],
#  'diabetes mellitus': ['Type 2 diabetes mellitus', 0.9585421],
#  'right ear': ['Blood test', 0.85159475],
#  'UTI': ['Lethargy', 0.80883795],
#  'INJECTION SITE ERYTHEMA': ['Erythema', 0.93002665],
#  'Cough': ['Cough', 1.0000002],
#  'irregular': ['Swelling', 0.9077648],
#  'seriousness criterion medically significant)': ['Drug ineffective',
#   0.79160976],
#  'head ache': ['Neck pain', 0.90529644],
#  'Sore arm': ['Neck pain', 0.86036223],
#  'ears': ['Seizure', 0.9329277],
#  'black': ['Anxiety', 0.85850966],
#  'SOB': ['Seizure', 0.9225701],
#  'INJECTION SITE SWELLING': ['Injection site pain', 0.9520793],
#  'hardness': ['Swelling', 0.9070461],
#  'PAIN IN EXTREMITY': ['Injection site pain', 0.8501483],
#  'injection site soreness': ['Injection site pain', 0.95225453],
#  'sore': ['Scar', 0.9173199],
#  'difficulty swallowing': ['Abdominal pain', 0.86773396],
#  'hemorrhage': ['Thrombosis', 0.8864828],
#  'PAIN IN EXTREMITY (non-serious)': ['Vaccination site pain', 0.8499581],
#  'CONDITION AGGRAVATED': ['Hypothyroidism', 0.7975027],
#  'acute': ['Illness', 0.8805956],
#  'Lightheaded': ['Tenderness', 0.8774801],
#  'Tinnitus': ['Tinnitus', 1.0000001],
#  'FATIGUE': ['Fatigue', 1.0],
#  'REACTION': ['Investigation', 0.87111896],
#  'BODY ACHE': ['Body temperature', 0.89013463],
#  'shock': ['Illness', 0.8926469],
#  'ERYTHEMA': ['Erythema', 1.0000002],
#  'FEELING ABNORMAL': ['Feeling cold', 0.90124226],
#  'flushed': ['Swelling', 0.89753425],
#  'drug allergy': ['Allergy to vaccine', 0.93125296],
#  'MYALGIA (Body aches)': ['Fibromyalgia', 0.89130545],
#  'erythema': ['Erythema', 1.0000002],
#  'sporadic': ['Rash', 0.8570393],
#  'collar bone': ['Brain fog', 0.86276406],
#  'herpes': ['Sepsis', 0.8494662],
#  'migraines': ['Migraine', 0.97398],
#  'virus': ['Infection', 0.88117385],
#  'Redness': ['Tenderness', 0.94456446],
#  'a temperature excursion': ['Pyrexia', 0.85782063],
#  'aches': ['Chills', 0.9098122],
#  'Low grade': ['Tenderness', 0.8535509],
#  'eczema': ['Eczema', 1.0000002],
#  'Itchiness': ['Pyrexia', 0.8744232],
#  'tongue swelling': ['Abdominal pain', 0.92160094],
#  'PRURITUS': ['Pruritus', 1.0000001],
#  'difficulty breathing': ['Abdominal pain', 0.863769],
#  'Concurrent medical conditions': ['Pericarditis', 0.83492655],
#  'confused': ['Cough', 0.8665486],
#  'thick': ['Scar', 0.88255537],
#  'The adverse event': ['No adverse event', 0.89711505],
#  'joints': ['Discomfort', 0.89286125],
#  'her leg': ['Abdominal pain', 0.82429886],
#  'inflammatory': ['Inflammation', 0.9363078],
#  'prior vaccination': ['Vaccination failure', 0.9543638],
#  'HYPERHIDROSIS': ['Hypothyroidism', 0.8846023],
#  'shoulder pain': ['Abdominal pain', 0.9555268],
#  'red swollen': ['Tenderness', 0.8541608],
#  'red': ['Swelling', 0.83552814],
#  'palpitations': ['Palpitations', 1.0],
#  'VACCINATION SITE ERYTHEMA': ['Vaccination site pain', 0.92641234],
#  'side effect': ['Drug ineffective', 0.8618926],
#  'mild fever': ['Abdominal pain', 0.8982339],
#  'hit': ['Scar', 0.88023365],
#  'arm hurt': ['Back pain', 0.87004286],
#  'AKI': ['Pyrexia', 0.8552805],
#  'all symptoms': ['Tenderness', 0.8775501],
#  'Muscle aches': ['Abdominal pain', 0.8934226],
#  'flushing': ['Vomiting', 0.9165651],
#  'mucus': ['Blister', 0.8402053],
#  'INJURY': ['Illness', 0.912433],
#  'death': ['Death', 0.9999999],
#  'redness': ['Tenderness', 0.94456446],
#  'muscle pain': ['Neck pain', 0.94349736],
#  'distress': ['Discomfort', 0.9443884],
#  'diabetes': ['Illness', 0.8947775],
#  'my heart': ['Heart rate', 0.88977396],
#  'other events': ['Abdominal pain', 0.8549712],
#  'low grade fever': ['Pyrexia', 0.89240116],
#  'welts': ['Chills', 0.8470634],
#  'severe chills': ['Abdominal pain', 0.8831779],
#  'relief': ['Fatigue', 0.90256935],
#  'wheezing': ['Dizziness', 0.86939394],
#  'the swelling': ['Swelling', 0.87654793],
#  'Allergies': ['Allergy to vaccine', 0.93429315],
#  'hypoxic respiratory failure': ['Hypothyroidism', 0.88203603],
#  'adverse effect': ['Adverse event', 0.91303706],
#  'adverse event': ['Adverse event', 1.0],
#  'NECK PAIN': ['Neck pain', 0.9999999],
#  'CHILLS': ['Chills', 1.0],
#  'dehydrated': ['Dehydration', 0.9489793],
#  'muscle sore': ['Tenderness', 0.897438],
#  'metallic taste': ['Burning sensation', 0.89073217],
#  'my neck': ['Neck pain', 0.87379515],
#  'unwell': ['Feeling cold', 0.82749856],
#  'Allergic': ['Allergy to vaccine', 0.889323],
#  'swollen arm': ['Abdominal pain', 0.8559258],
#  'symptomatic': ['Dehydration', 0.79039884],
#  'bruise': ['Blister', 0.8826825],
#  'MR': ['Pyrexia', 0.82630754],
#  'AXILLARY PAIN': ['Fibromyalgia', 0.8615958],
#  'red area': ['Tenderness', 0.86664355],
#  'swelled': ['Swelling', 0.94692254],
#  'her mouth': ['Brain fog', 0.859836],
#  'dark': ['Anxiety', 0.8580031],
#  'vaccination site': ['Vaccination site swelling', 0.9852193],
#  'TENDER': ['Discomfort', 0.90707594],
#  'the injection site': ['Injection site pain', 0.8941026],
#  'muscle weakness': ['Tenderness', 0.882288],
#  'Achy': ['Pyrexia', 0.8433213],
#  'ns': ['Chills', 0.81203985],
#  'labor': ['Seizure', 0.9120983],
#  'my symptoms': ['Tenderness', 0.8768116],
#  'episodes': ['Illness', 0.90634423],
#  'insomnia': ['Insomnia', 1.0],
#  'any side effect': ['No adverse event', 0.8964653],
#  'RASH': ['Rash', 1.0000002],
#  'throat': ['Cough', 0.9340446],
#  'light headache': ['Vomiting', 0.89429975],
#  'bronchitis': ['Cellulitis', 0.878948],
#  'CONGESTION': ['Swelling', 0.92738724],
#  'fainting': ['Vomiting', 0.9136364],
#  'adverse effects': ['Adverse event', 0.8654872],
#  'Vaccination site pain': ['Vaccination site pain', 1.0000001],
#  'abnormal)': ['Swelling', 0.88187313],
#  'Injection Site': ['Injection site pain', 0.91822743],
#  'seizures': ['Chills', 0.9028789],
#  'palsy': ["Bell's palsy", 0.8926965],
#  'left foot': ['Abdominal pain', 0.83442473],
#  'sleepy': ['Headache', 0.88103044],
#  'loss of smell': ['Vertigo', 0.8463993],
#  'a little sore': ['Tenderness', 0.8468845],
#  'chills': ['Chills', 1.0],
#  'lesions': ['Scar', 0.91301763],
#  'puffy': ['Pyrexia', 0.8488817],
#  'sunburn': ['Tenderness', 0.89334315],
#  'blister': ['Blister', 0.9999999],
#  'chest pain': ['Chest pain', 0.9999998],
#  'Rheumatoid arthritis': ['Rheumatoid arthritis', 0.9999999],
#  'pain at injection site': ['Injection site pain', 0.94663996],
#  'hypertension': ['Hypertension', 1.0],
#  'a lot of pain': ['Injection site pain', 0.8804278],
#  'sensitive': ['Swelling', 0.8933575],
#  'dull': ['Headache', 0.86154795],
#  'asymptomatic': ['Dehydration', 0.7749188],
#  'ARTHRALGIA': ['Arthralgia', 1.0],
#  'Nauseous': ['Pyrexia', 0.8321516],
#  'his symptoms': ['Tenderness', 0.8845599],
#  'soreness': ['Tenderness', 0.95982194],
#  'consciousness': ['Seizure', 0.9120856],
#  'PAIN IN EXTREMITY (Sore arm': ['Vaccination site pain', 0.8381928],
#  'loose': ['Seizure', 0.90923953],
#  'FATIGUE (Fatigue': ['Tenderness', 0.8509509],
#  'AESI': ['Pyrexia', 0.8499966],
#  'drug ineffective': ['Drug ineffective', 1.0],
#  'slight headache': ['Abdominal pain', 0.87117517],
#  'PE': ['Pyrexia', 0.8589456],
#  'prob': ['X-ray', 0.7835988],
#  'PAIN IN EXTREMITY (Pain': ['Injection site pain', 0.8634057],
#  'cp': ['COVID-19', 0.81088144],
#  'Tender': ['Discomfort', 0.90707594],
#  'vaccination failure': ['Vaccination failure', 1.0000002],
#  'DYSPNOEA': ['Pyrexia', 0.84525734],
#  'the temp': ['Interchange of vaccine products', 0.830657],
#  'severe pain': ['Abdominal pain', 0.95379883],
#  'this event': ['Vertigo', 0.851065],
#  'adverse reaction': ['Adverse event', 0.937274],
#  'The symptoms': ['Tenderness', 0.87433803],
#  'nauseous': ['Pyrexia', 0.8321516],
#  'trouble breathing': ['Abdominal pain', 0.8832984],
#  'COVID-19': ['COVID-19', 0.9999999],
#  'disability': ['Discomfort', 0.89066845],
#  'Swollen lymph node': ['Pericarditis', 0.8397387],
#  'chronic': ['Scar', 0.88709706],
#  'hot': ['Headache', 0.85722566],
#  'ASE': ['Swelling', 0.8383367],
#  'vertigo': ['Vertigo', 1.0000002],
#  'warm': ['Swelling', 0.8896263],
#  'cough': ['Cough', 1.0000002],
#  'The events': ['Brain fog', 0.8298757],
#  'myocarditis': ['Myocarditis', 1.0000001],
#  'very pain': ['Abdominal pain', 0.8857923],
#  'Weak': ['Nausea', 0.8585688],
#  'flu-like symptoms': ['Pyrexia', 0.8817978],
#  'hair loss': ['Tenderness', 0.87574327],
#  'leg pain': ['Neck pain', 0.95427495],
#  'her body': ['Body temperature', 0.8599066],
#  'unresponsive': ['Dehydration', 0.7538325],
#  'pyrexia': ['Pyrexia', 1.0],
#  'sob': ['Seizure', 0.9225701],
#  'events': ['Illness', 0.8987268],
#  'pruritus': ['Pruritus', 1.0000001],
#  'abdominal pain': ['Abdominal pain', 1.0000002],
#  'RASH (Rash': ['Rash', 0.91671556],
#  'other symptom': ['Blister', 0.8045082],
#  'muscle spasms': ['Pyrexia', 0.8834251],
#  'Chest pain': ['Chest pain', 0.9999998],
#  'temporal association': ['Brain fog', 0.8624691],
#  'fatigued': ['Fatigue', 0.8619992],
#  'papules': ['Palpitations', 0.8892396],
#  'Fatigue': ['Fatigue', 1.0],
#  'achy': ['Pyrexia', 0.8433213],
#  'vision': ['Swelling', 0.8858938],
#  'Swelling': ['Swelling', 0.9999998],
#  'obesity': ['Abdominal pain', 0.87489134],
#  'migraine': ['Migraine', 1.0],
#  'a red': ['Tenderness', 0.849398],
#  'nausea,': ['Vomiting', 0.8663686],
#  'influenza': ['Pneumonia', 0.8814239],
#  'adalimumab': ['Lethargy', 0.7677462],
#  'hypothyroidism': ['Hypothyroidism', 0.9999996],
#  'heart attack': ['Heart rate', 0.90049577],
#  'hot.': ['Chills', 0.85578483],
#  'mono': ['Vitamin D', 0.78028727],
#  'itches': ['Vomiting', 0.88050467],
#  'hypothyroid': ['Hypothyroidism', 0.9616902],
#  'BURNING SENSATION': ['Burning sensation', 1.0000002],
#  'left arm pain': ['Abdominal pain', 0.8977995],
#  'DIARRHOEA (Diarrhea': ["Crohn's disease", 0.847481],
#  'dizz': ['Pyrexia', 0.8026191],
#  'my chest': ['Chest pain', 0.90492105],
#  'pandemic': ['Vaccination site swelling', 0.8274035],
#  'ADVERSE EVENT': ['Adverse event', 1.0],
#  'OVERDOSE': ['Vomiting', 0.8503338],
#  'myalgia': ['Myalgia', 1.0000002],
#  'warmth': ['Anxiety', 0.90541744],
#  'vomit': ['Seizure', 0.9391538],
#  'spasms': ['Pyrexia', 0.8708868],
#  'Arm pain': ['Neck pain', 0.958802],
#  'any adverse event': ['No adverse event', 0.9678256],
#  'known allergies': ['Allergy to vaccine', 0.9256422],
#  'swollen lymph nodes': ['Pericarditis', 0.8309663],
#  'ILLNESS': ['Illness', 1.0000001],
#  'shaky': ['Seizure', 0.9043499],
#  'clinical vaccination failure': ['Vaccination failure', 0.978174],
#  'RED': ['Swelling', 0.83552814],
#  'any temperature excursion': ['Body temperature', 0.867329],
#  'the flu': ['Tenderness', 0.85285234],
#  'Sick': ['Seizure', 0.938822],
#  'MUSCULOSKELETAL STIFFNESS': ['Knee arthroplasty', 0.80159926],
#  'temperature excursions': ['Body temperature', 0.87159914],
#  'Chills': ['Chills', 1.0],
#  'ALLERGY': ['Allergy to vaccine', 0.94122577],
#  'ear pain': ['Abdominal pain', 0.933358],
#  'the reported events': ['Vertigo', 0.8412956],
#  'painful': ['Discomfort', 0.93042517],
#  'VACCINATION SITE SWELLING': ['Vaccination site swelling', 1.0],
#  'weak': ['Nausea', 0.8585688],
#  'PAIN (pain': ['Injection site pain', 0.89718777],
#  'Myalgia': ['Myalgia', 1.0000002],
#  'Red': ['Swelling', 0.83552814],
#  'Pain': ['Pain', 1.0],
#  'tightness': ['Tenderness', 0.9273683],
#  'very sick': ['Drug ineffective', 0.85588723],
#  'positive': ['Nausea', 0.86231905],
#  'neck pain': ['Neck pain', 0.9999999],
#  'Low grade fever': ['Pyrexia', 0.89240116],
#  'malaise': ['Dizziness', 0.86446536],
#  'bacteria': ['Illness', 0.88748515],
#  'FEELING HOT': ['Feeling cold', 0.9429779],
#  'rheumatoid arthritis': ['Rheumatoid arthritis', 0.9999999],
#  'numbness': ['Tenderness', 0.9600624],
#  'injection site sore': ['Injection site pain', 0.9486346],
#  'throat swelling': ['Abdominal pain', 0.9172882],
#  'hypoxia': ['Dehydration', 0.870636],
#  'bleed': ['Scar', 0.9099096],
#  'Hot': ['Headache', 0.85722566],
#  'injection': ['Injection', 1.0],
#  'The pain': ['Abdominal pain', 0.8638716],
#  'positive test': ['Blood test', 0.88967955],
#  'DISTURBANCE': ['Discomfort', 0.9376926],
#  'inflamed': ['Myocarditis', 0.8348384],
#  'little tired': ['Feeling cold', 0.8560414],
#  '"pain': ['Chest pain', 0.85331905],
#  'aki': ['Pyrexia', 0.8552805],
#  'the headache': ['Brain fog', 0.869221],
#  'fever of 101': ['Interchange of vaccine products', 0.8331624],
#  'Tired': ['Headache', 0.86031115],
#  'BNT162b2': ['SARS-CoV-2 test', 0.8446757],
#  'stomach pain': ['Abdominal pain', 0.94963115],
#  'throbbing': ['Seizure', 0.92951405],
#  'dyspnea': ['Pyrexia', 0.87688315],
#  'PAIN IN EXTREMITY (sore arm)': ['Injection site pain', 0.8485743],
#  'additional non-serious events': ['No adverse event', 0.88985544],
#  'muscle ache': ['Tenderness', 0.8883846],
#  'bruising': ['Blister', 0.8598856],
#  'congested': ['Lethargy', 0.8497123],
#  'clot': ['Brain fog', 0.86742854],
#  'the adverse events': ['No adverse event', 0.88446647],
#  'left leg': ['Abdominal pain', 0.8336961],
#  'attacks': ['Illness', 0.90575266],
#  'uti': ['Lethargy', 0.80883795],
#  'respiratory failure': ['Abdominal pain', 0.9002433],
#  'thrombosis': ['Thrombosis', 1.0],
#  'pre-existing medical condition': ['Pericarditis', 0.83881426],
#  'Vaccination site': ['Vaccination site swelling', 0.9852193],
#  'excursions': ['Brain fog', 0.8588532],
#  'mild': ['Nausea', 0.870225],
#  'hot flashes': ['Abdominal pain', 0.896962],
#  'PRODUCT TEMPERATURE EXCURSION ISSUE': ['Interchange of vaccine products',
#   0.8472539],
#  'Pneumonia': ['Pneumonia', 1.0],
#  'Headache': ['Headache', 1.0],
#  'spasm': ['Tenderness', 0.88388157],
#  'MYALGIA (Body aches': ['Fibromyalgia', 0.8929507],
#  'scar': ['Scar', 1.0],
#  'Burning': ['Swelling', 0.91586185],
#  'any symptoms': ['Abdominal pain', 0.8778494],
#  'MYALGIA (body aches)': ['Fibromyalgia', 0.89130545],
#  'tender': ['Discomfort', 0.90707594],
#  'joint ache': ['Tenderness', 0.8792223],
#  'weakness': ['Anxiety', 0.9275498],
#  'outbreak': ['Pneumonia', 0.8955042],
#  'light headed': ['Brain fog', 0.8685825],
#  'NAUSEA (Nausea)': ['Pyrexia', 0.8849856],
#  'Depression': ['Depression', 0.9999999],
#  'arm sore': ['Neck pain', 0.8984879],
#  'Lightheadness': ['Tenderness', 0.873255],
#  'feeling unwell': ['Feeling cold', 0.89768505],
#  'the heart': ['Heart rate', 0.86567026],
#  'PAIN (non-serious)': ['No adverse event', 0.83636284],
#  'Stiffness': ['Tenderness', 0.90349066],
#  'hyperlipidemia': ['Hypertension', 0.8907864],
#  'anaphylactic reaction': ['Allergy to vaccine', 0.8472613],
#  'Mild': ['Nausea', 0.870225],
#  'loss of taste': ['Vertigo', 0.86162716],
#  'etc': ['Scar', 0.8826929],
#  'cold': ['Anxiety', 0.8822789],
#  'vaccinated': ['Vaccination failure', 0.9481137],
#  'high blood pressure': ['Blood pressure measurement', 0.9222864],
#  'immunisation': ['Immunisation', 1.0000002],
#  'swelling at injection site': ['Injection site pain', 0.9069276],
#  'pus': ['Chills', 0.863118],
#  'foggy': ['Brain fog', 0.89596784],
#  'Adverse events': ['Adverse event', 0.95023],
#  'a headache': ['Pyrexia', 0.87404704],
#  'a flu': ['Pyrexia', 0.8601458],
#  'heart palpitations': ['Palpitations', 0.96629417],
#  'coughing': ['Cough', 0.94967586],
#  'flare': ['Headache', 0.90986246],
#  'reflux': ['Blister', 0.8504313],
#  'HF': ['Brain fog', 0.81550676],
#  'the blood': ['Tenderness', 0.8396047],
#  'lymph node': ['Pericarditis', 0.82150453],
#  'Migraine': ['Migraine', 1.0],
#  'FATIGUE (fatigue)': ['Tenderness', 0.8631501],
#  'STI': ['Brain fog', 0.7915522],
#  'thirst': ['Anxiety', 0.91289604],
#  'achy)': ['Pyrexia', 0.8372486],
#  'Joint pain': ['Neck pain', 0.94620824],
#  'palpitation': ['Palpitations', 0.95846266],
#  'adenopathy': ['Pyrexia', 0.8882887],
#  'arm soreness': ['Tenderness', 0.9120035],
#  'injury': ['Illness', 0.912433],
#  '-Mild': ['Drug ineffective', 0.8585876],
#  'INFLUENZA LIKE ILLNESS': ['Sepsis', 0.86509347],
#  'blurry': ['Brain fog', 0.87140536],
#  'Dizziness': ['Dizziness', 1.0],
#  'head to toe': ['Blood test', 0.79010177],
#  'fatigue': ['Fatigue', 1.0],
#  'bone pain': ['Neck pain', 0.94158846],
#  'talking': ['Swelling', 0.899919],
#  'Itchy': ['Tenderness', 0.86370736],
#  'chest tightness': ['Tenderness', 0.9069315],
#  'Sore thro': ['Lethargy', 0.83098257],
#  'severity': ['Anxiety', 0.91667163],
#  'throwing': ['Vomiting', 0.87048393],
#  'concomitant product': ['Interchange of vaccine products', 0.7900295],
#  'little sore': ['Tenderness', 0.8518511],
#  'a flare': ['Tenderness', 0.8710385],
#  'a stroke': ['Sepsis', 0.8845055],
#  'a temperature': ['Body temperature', 0.86573887],
#  'stiff': ['Swelling', 0.8688412],
#  'the itching': ['Tenderness', 0.83616483],
#  'severe body aches': ['Abdominal pain', 0.8800177],
#  'low grade': ['Tenderness', 0.8535509],
#  'Headaches': ['Back pain', 0.8869767],
#  'COPD': ['Swelling', 0.81796145],
#  'the area': ['Tenderness', 0.82309043],
#  'atrial fibrillation': ['Atrial fibrillation', 0.99999994],
#  'Inflammation': ['Inflammation', 1.0000001],
#  'egs': ['Scar', 0.819812],
#  'her symptoms': ['Tenderness', 0.88726217],
#  'an itch': ['Pyrexia', 0.859764],
#  'seizure': ['Seizure', 1.0],
#  'muscles': ['Anxiety', 0.88052624],
#  'responsive': ['SARS-CoV-2 test', 0.75301343],
#  'severe headache': ['Abdominal pain', 0.90585643],
#  'tingly': ['Vomiting', 0.85305524],
#  'Brain fog': ['Brain fog', 0.9999999],
#  'INDURATION': ['Pyrexia', 0.8705642],
#  'ached': ['Seizure', 0.92909586],
#  'NAUSEA': ['Nausea', 1.0000001],
#  'other pre-existing medical conditions': ['Pericarditis', 0.8305213],
#  'concomitant medication information': ['Vaccination site pain', 0.82766074],
#  'headache': ['Headache', 1.0],
#  'SWELLING (Swelling': ['Swelling', 0.8728603],
#  'reactions': ['Investigation', 0.89478135],
#  'shooting pain': ['Abdominal pain', 0.93633944],
#  'miscarriage': ['Vaccination failure', 0.7973727],
#  'fevers': ['Chills', 0.88403857],
#  'AML': ['Injection', 0.8020129],
#  'SYNCOPE': ['Syncope', 1.0000002],
#  'TREMOR': ['Tremor', 0.99999994],
#  'tension': ['Discomfort', 0.9174971],
#  'N': ['Seizure', 0.8526894],
#  'allergic': ['Allergy to vaccine', 0.889323],
#  'scratchy': ['Feeling cold', 0.8437525],
#  'drainage': ['Swelling', 0.9203214],
#  'severe body ache': ['Abdominal pain', 0.9097159],
#  'same symptoms': ['Tenderness', 0.87622195],
#  'Dizzy': ['Seizure', 0.9452485],
#  'a sore throat': ['Neck pain', 0.88942313],
#  'the adverse event': ['No adverse event', 0.89711505],
#  'terrible': ['Seizure', 0.9066131],
#  'the redness': ['Tenderness', 0.90146947],
#  'nausea': ['Nausea', 1.0000001],
#  'red rash': ['Rash', 0.95187867],
#  'fibrillation': ['Atrial fibrillation', 0.929047],
#  'antibodies': ['Anxiety', 0.90697753],
#  'PARAESTHESIA': ['Pyrexia', 0.8593046],
#  'a deep breath': ['Burning sensation', 0.8256416],
#  'the chills': ['Chills', 0.88928044],
#  'lethargy': ['Lethargy', 1.0],
#  'injection site pain': ['Injection site pain', 1.0],
#  'sore arm)': ['Blood test', 0.86255026],
#  'confusion': ['Anxiety', 0.9016314],
#  'nauseated': ['Vomiting', 0.90532213],
#  'PYREXIA': ['Pyrexia', 1.0],
#  'VACCINATION SITE ERYTHEMA (Redness': ['Vaccination site pain', 0.90090024],
#  'Adverse event': ['Adverse event', 1.0],
#  'voice': ['Cough', 0.8228657],
#  'Pain in arm': ['Injection site pain', 0.9070935],
#  'symptom': ['Injection site pain', 0.8105614],
#  'extreme pain': ['Abdominal pain', 0.95355105],
#  'CHEST DISCOMFORT': ['Chest pain', 0.9483433],
#  'bleeding': ['Scar', 0.916025],
#  'the symptoms': ['Tenderness', 0.87433803],
#  'PAIN IN EXTREMITY (sore arm': ['Vaccination site pain', 0.8381928],
#  'arm pain': ['Neck pain', 0.958802],
#  'signs': ['Swelling', 0.9085206],
#  'vomiting': ['Vomiting', 0.9999999],
#  'MS': ['Chills', 0.8301873],
#  'a seizure': ['Pyrexia', 0.8801924],
#  'Symptoms': ['Anxiety', 0.9378116],
#  'raised': ['Anxiety', 0.8857315],
#  'Sweating': ['Scar', 0.9226016],
#  'allergies': ['Allergy to vaccine', 0.93429315],
#  'pain at the injection site': ['Injection site pain', 0.91436934],
#  'VERTIGO': ['Vertigo', 1.0000002],
#  'seriousness criteria': ['Tenderness', 0.8662425],
#  'Red rash': ['Rash', 0.95187867],
#  'left arm pit': ['Abdominal pain', 0.8527455],
#  'extreme fatigue': ['Fatigue', 0.89848423],
#  'anaphylaxis': ['Tachycardia', 0.8257596],
#  'discharge': ['Discharge', 1.0000002],
#  'an allergic reaction': ['Allergy to vaccine', 0.9179644],
#  'a sore arm': ['Neck pain', 0.85943246],
#  'my throat': ['Neck pain', 0.8722927],
#  'the side effects': ['Injection site pain', 0.8267237],
#  'Body ache': ['Body temperature', 0.89013463],
#  'allergic reaction': ['Allergy to vaccine', 0.91363335],
#  'SOMNOLENCE': ['Insomnia', 0.85538214],
#  'mild symptoms': ['Abdominal pain', 0.89514303],
#  'condition': ['Anxiety', 0.8769495],
#  'vomited': ['Vomiting', 0.9245949],
#  'shortness': ['Tenderness', 0.90103364],
#  'red spot': ['Rash', 0.86597097],
#  'the fever': ['Sepsis', 0.8685108],
#  'her tongue': ['Abdominal pain', 0.8549713],
#  'exhaustion': ['Fatigue', 0.9243329],
#  'clammy': ['Fibromyalgia', 0.8637977],
#  'WEAKNESS': ['Anxiety', 0.9275498],
#  'flu like symptoms': ['Pyrexia', 0.8897729],
#  'adverse events': ['Adverse event', 0.95023],
#  'tumor': ['Illness', 0.8858788],
#  'event': ['Fall', 0.8671416],
#  'the event': ['Brain fog', 0.8405404],
#  'effusion': ['Vertigo', 0.84583724],
#  'upset stomach': ['Vomiting', 0.86389726],
#  'INFECTION': ['Infection', 0.9999999],
#  'tinnitus': ['Tinnitus', 1.0000001],
#  'stabbing': ['Swelling', 0.9079506],
#  'any adverse reaction': ['No adverse event', 0.9331442],
#  'Flu like symptoms': ['Pyrexia', 0.8897729],
#  'infarct': ['Myocarditis', 0.8303937],
#  'Vomiting': ['Vomiting', 0.9999999],
#  'pain in extremity': ['Injection site pain', 0.8501483],
#  'ha': ['Swelling', 0.81766707],
#  'VACCINATION SITE PAIN': ['Vaccination site pain', 1.0000001],
#  'LYMPHADENOPATHY': ['Pericarditis', 0.86762166],
#  'very itch': ['Tenderness', 0.8516594],
#  'spike': ['Headache', 0.8852588],
#  'very dizzy': ['Vomiting', 0.8643291],
#  'pain': ['Pain', 1.0],
#  'Rash': ['Rash', 1.0000002],
#  'body pain': ['Abdominal pain', 0.9403656],
#  'DIZZINESS': ['Dizziness', 1.0],
#  'anxiety': ['Anxiety', 1.0],
#  'ringing': ['Swelling', 0.9144932],
#  'adverse reactions': ['Adverse event', 0.90044606],
#  'heat': ['Pain', 0.8631458],
#  'seriousness': ['Tenderness', 0.893111],
#  'high fever': ['Sepsis', 0.8963657],
#  'INFLAMMATION': ['Inflammation', 1.0000001],
#  'pain in the arm': ['Injection site pain', 0.87720466],
#  'PALPITATIONS': ['Palpitations', 1.0],
#  'soreness at the injection site': ['Injection site pain', 0.8911373],
#  'sensitivity': ['Anxiety', 0.9015943],
#  'medically significant)': ['Drug ineffective', 0.78769445],
#  'medical conditions': ['Drug ineffective', 0.883426],
#  'the itch': ['Blister', 0.8474771],
#  'itchy rash': ['Rash', 0.9315733],
#  'a little bit': ['Feeling cold', 0.7389966],
#  'hypersensitivity': ['Allergy to vaccine', 0.7748175],
#  'blood pressure': ['Blood pressure measurement', 0.94583523],
#  "Bell's Palsy": ["Bell's palsy", 0.9999999],
#  'vaccination site pain': ['Vaccination site pain', 1.0000001],
#  'pressure': ['Anxiety', 0.89515734],
#  'HYPERSENSITIVITY': ['Allergy to vaccine', 0.7748175],
#  'her neck': ['Neck pain', 0.88506407],
#  'swallowing': ['Swelling', 0.8975155],
#  'immunocompromised': ['Immunisation', 0.80413926],
#  'enlarged': ['Swelling', 0.92139006],
#  'diabetic': ['Type 2 diabetes mellitus', 0.88207465],
#  'Seizure': ['Seizure', 1.0],
#  'REDNESS': ['Tenderness', 0.94456446],
#  'hive': ['Pneumonia', 0.82596505],
#  'DECREASED APPETITE': ['Burning sensation', 0.86399215],
#  'problems': ['Headache', 0.8949853],
#  'VACCINATION SITE': ['Vaccination site swelling', 0.9852193],
#  'very fatigue': ['Fatigue', 0.88081616],
#  'sensation': ['Anxiety', 0.9283568],
#  'red and swollen': ['Tenderness', 0.8730769],
#  'shingles': ['Brain fog', 0.8477738],
#  'FATIGUE (non-serious)': ['No adverse event', 0.84036183],
#  'Asthma': ['Asthma', 1.0],
#  'autoimmune': ['Immunisation', 0.8470546],
#  'crap': ['Seizure', 0.94008446],
#  'frequency': ['Scar', 0.8876846],
#  'GERD': ['Pyrexia', 0.8280729],
#  'smell': ['Cough', 0.88310784],
#  'Hot flash': ['Blood test', 0.84801257],
#  'INFLUENZA': ['Pneumonia', 0.8814239],
#  'strength': ['Fatigue', 0.8669629],
#  'hypotension': ['Hypothyroidism', 0.8989028],
#  'Tiredness': ['Tenderness', 0.921204],
#  'tenderness': ['Tenderness', 0.99999994],
#  'body aches': ['Abdominal pain', 0.895549],
#  'COUGH': ['Cough', 1.0000002],
#  'TACHYCARDIA': ['Tachycardia', 1.0000001],
#  'bright red': ['Tenderness', 0.83631694],
#  'short of breath': ['Heart rate', 0.7975395],
#  'STIFF': ['Swelling', 0.8688412],
#  'NAD': ['COVID-19', 0.83222157],
#  'ulcer': ['Ulcer', 0.9999998],
#  'the pain': ['Abdominal pain', 0.8638716],
#  'light fever': ['Sepsis', 0.8844207],
#  'heaviness': ['Tenderness', 0.86180615],
#  'pain in arm': ['Injection site pain', 0.9070935],
#  'rapid heart': ['Heart rate', 0.89176977],
#  'falls': ['Fall', 0.9620004],
#  'swollen': ['Swelling', 0.9506608],
#  'lethargic': ['Lethargy', 0.96875286],
#  'her throat': ['Abdominal pain', 0.88198274],
#  'a cough': ['Cough', 0.86464894],
#  'ACHES': ['Chills', 0.9098122],
#  'Covid': ['COVID-19', 0.85596645],
#  'issues': ['Investigation', 0.90165555],
#  'ADR': ['Lethargy', 0.8182212],
#  'Itching': ['Tenderness', 0.8921311],
#  'flashes': ['Swelling', 0.9127097],
#  'hurting': ['Seizure', 0.9315643],
#  'VACCINATION SITE INDURATION': ['Vaccination site pain', 0.95606315],
#  'psoriasis': ['Psoriasis', 1.0000001],
#  'MIS': ['Brain fog', 0.84422326],
#  'Severe headache': ['Abdominal pain', 0.90585643],
#  'nose': ['Headache', 0.88156486],
#  'discomfort': ['Discomfort', 1.0],
#  'allergy': ['Allergy to vaccine', 0.94122577],
#  'damage': ['Swelling', 0.90478575],
#  'ACCIDENTAL OVERDOSE': ['Pyrexia', 0.82894725],
#  'URTICARIA': ['Urticaria', 0.99999976],
#  'COVID-19 positive': ['COVID-19 pneumonia', 0.94550586],
#  'other vaccines': ['Interchange of vaccine products', 0.90528554],
#  'Unresponsive': ['Dehydration', 0.7538325],
#  'SWOLLEN': ['Swelling', 0.9506608],
#  'abnormal': ['Discomfort', 0.9052503],
#  'Sore arm)': ['Blood test', 0.86255026],
#  'Muscle pain': ['Neck pain', 0.94349736],
#  'heart beat': ['Heart rate', 0.9365586],
#  'my ears': ['Tenderness', 0.85398614],
#  'soreness at injection site': ['Injection site pain', 0.9095659],
#  'life threatening)': ['Drug ineffective', 0.85810435],
#  'sinuses': ['Brain fog', 0.8461987],
#  'cancer': ['Illness', 0.8762268],
#  'blurry vision': ['Dizziness', 0.87864226],
#  'thrombocytopenia': ['Thrombosis', 0.87660134],
#  'hives': ['Pneumonia', 0.8443407],
#  'blurred vision': ['Abdominal pain', 0.8823637],
#  '-Medium': ['Drug ineffective', 0.84292614],
#  'extremely tired': ['Feeling cold', 0.8546171],
#  'freezing': ['Swelling', 0.89312136],
#  'numb': ['Scar', 0.91617304],
#  'congestion': ['Swelling', 0.92738724],
#  'appetite': ['Anxiety', 0.9009696],
#  'the vaccination site': ['Vaccination site swelling', 0.9556503],
#  'shakes': ['Swelling', 0.92231226],
#  'twitching': ['Vomiting', 0.905076],
#  'HIV': ['Infection', 0.71736366],
#  'Allergy': ['Allergy to vaccine', 0.94122577],
#  'deep breath': ['Blood test', 0.8302084],
#  'reaction': ['Investigation', 0.87111896],
#  'stroke': ['Illness', 0.86876637],
#  'dehydration': ['Dehydration', 1.0],
#  'diarrhea': ['Dizziness', 0.87067735],
#  'mass': ['Mass', 1.0],
#  'a reaction': ['Blood test', 0.844616],
#  'blood sugar': ['Blood pressure measurement', 0.9275105],
#  'COVID19': ['COVID-19', 0.9058149],
#  'The event': ['Brain fog', 0.8405404],
#  'twitch': ['Swelling', 0.9168768],
#  'MATERNAL EXPOSURE': ['Sepsis', 0.8421631],
#  'a pain': ['Chest pain', 0.8736708],
#  'VT': ['COVID-19', 0.76571923],
#  'HYPOAESTHESIA': ['Hypothyroidism', 0.8651724],
#  'visual changes': ['Tenderness', 0.8886502],
#  'shivering': ['Anxiety', 0.9204587],
#  'urticaria': ['Urticaria', 0.99999976],
#  'ache': ['Seizure', 0.9457807],
#  'Hives': ['Pneumonia', 0.8443407],
#  'hot to the touch': ['Feeling cold', 0.83077013],
#  'flu symptoms': ['Abdominal pain', 0.89715445],
#  'illness': ['Illness', 1.0000001],
#  'difficulty': ['Discomfort', 0.94515353],
#  'tiredness': ['Tenderness', 0.921204],
#  'night sweats': ['Brain fog', 0.8709861],
#  'dizzy': ['Seizure', 0.9452485],
#  'ABNORMAL': ['Discomfort', 0.9052503],
#  'bump': ['Scar', 0.9077853],
#  'stomach cramps': ['Pyrexia', 0.86188376],
#  'bones': ['Discomfort', 0.91124743],
#  'type 2': ['Vitamin D', 0.829687],
#  'Flu': ['Swelling', 0.88419783],
#  'Nausea': ['Nausea', 1.0000001],
#  'back pain': ['Back pain', 1.0],
#  'HTN': ['SARS-CoV-2 test', 0.82430756],
#  'breathing': ['Anxiety', 0.88976526],
#  'the rash': ['Rash', 0.91543055],
#  'RHEUMATOID ARTHRITIS': ['Rheumatoid arthritis', 0.9999999],
#  'muscle aches': ['Abdominal pain', 0.8934226],
#  'uncomfortable': ['Discomfort', 0.9415554],
#  'excruciating': ['Pruritus', 0.7886487],
#  'infection': ['Infection', 0.9999999],
#  'MALAISE': ['Dizziness', 0.86446536],
#  'blisters': ['Blister', 0.97146505],
#  'Severe pain': ['Abdominal pain', 0.95379883],
#  'tense': ['Seizure', 0.9154923],
#  'the cough': ['Cough', 0.87338877],
#  'B2': ['Vitamin D', 0.81878686],
#  'exhausted': ['Fatigue', 0.89222676],
#  'edema': ['Eczema', 0.8883431],
#  's/t': ['Thrombosis', 0.7304323],
#  'DM': ['Vitamin D', 0.8183347],
#  'a heart attack': ['Syncope', 0.877131],
#  'NASOPHARYNGITIS': ['Fibromyalgia', 0.85658264],
#  'FEVER': ['Illness', 0.9041469],
#  'INJECTION SITE': ['Injection site pain', 0.91822743],
#  'a rash': ['Rash', 0.93874764],
#  'mild headache': ['Abdominal pain', 0.8870833],
#  'fever of 102': ['Interchange of vaccine products', 0.82705534],
#  'hot to touch': ['Feeling cold', 0.84115535],
#  'the events': ['Brain fog', 0.8298757],
#  'burn': ['Scar', 0.9189086],
#  'CHILL': ['Anxiety', 0.912954],
#  'tired': ['Headache', 0.86031115],
#  'rebound': ['Rash', 0.8738463],
#  'VOMITING': ['Vomiting', 0.9999999],
#  'energy': ['Anxiety', 0.86254495],
#  'VACCINATION SITE WARMTH': ['Vaccination site swelling', 0.9885677],
#  'inflammation': ['Inflammation', 1.0000001],
#  'tested positive': ['Blood test', 0.878278],
#  'CHEST PAIN': ['Chest pain', 0.9999998],
#  'night sweat': ['Brain fog', 0.8861236],
#  'Sore throat': ['Neck pain', 0.9075695],
#  'very red': ['Tenderness', 0.85419303],
#  'a fever': ['Sepsis', 0.8826268],
#  'irritation': ['Discomfort', 0.94760346],
#  'OSA': ['Chills', 0.8384607],
#  'sweating': ['Scar', 0.9226016],
#  'Extreme fatigue': ['Fatigue', 0.89848423],
#  'VACCINATION FAILURE': ['Vaccination failure', 1.0000002],
#  'syncope': ['Syncope', 1.0000002],
#  'NAUSEA (nausea)': ['Pyrexia', 0.8849856],
#  'c/o': ['COVID-19', 0.75650954],
#  'sx': ['Infection', 0.77278316],
#  'excruciating pain': ['Pruritus', 0.84631896],
#  'GAIT DISTURBANCE': ['Dizziness', 0.9006374],
#  'The symptom': ['Blister', 0.8176633],
#  'BACK PAIN': ['Back pain', 1.0],
#  'blood clots': ['Thrombosis', 0.8919799],
#  'PHN': ['Lethargy', 0.8525971],
#  'soa': ['Vomiting', 0.81506616],
#  'PERIPHERAL SWELLING': ['Tenderness', 0.8851783],
#  'my left arm': ['Tremor', 0.8029163],
#  'a bump': ['Brain fog', 0.878995],
#  'Muscle ache': ['Tenderness', 0.8883846],
#  'RHINORRHOEA': ['Fibromyalgia', 0.8522514],
#  'sneezing': ['Blister', 0.8498607],
#  'hair': ['Swelling', 0.8933184],
#  'sore throat': ['Neck pain', 0.9075695],
#  'ARTHRITIS': ['Arthritis', 0.9999999],
#  'Shortness of breath': ['Dizziness', 0.8203939],
#  'vaccination': ['Vaccination failure', 0.9691125],
#  'lump': ['Seizure', 0.92915714],
#  'PRURITUS (itchiness': ['Pruritus', 0.91945404],
#  'COVID': ['COVID-19', 0.85596645]}

# %%
df = pd.DataFrame(similarity_scores.items(), columns=['key','values'])

# %%
df
# Out:
#                      key                            values
# 0                  stool             [Swelling, 0.9072527]
# 1        lightheadedness            [Dizziness, 0.9160143]
# 2                fainted             [Vomiting, 0.8686165]
# 3              itchiness              [Pyrexia, 0.8744232]
# 4                MYALGIA              [Myalgia, 1.0000002]
# ..                   ...                               ...
# 995  Shortness of breath            [Dizziness, 0.8203939]
# 996          vaccination  [Vaccination failure, 0.9691125]
# 997                 lump             [Seizure, 0.92915714]
# 998  PRURITUS (itchiness            [Pruritus, 0.91945404]
# 999                COVID            [COVID-19, 0.85596645]
#
# [1000 rows x 2 columns]

# %%
# # Example tokenization and embedding
# symptom_text = "fever"
# standard_symptom_text = "migraine"

# symptom_tokens = tokenizer(symptom_text, return_tensors='pt')
# standard_symptom_tokens = tokenizer(standard_symptom_text, return_tensors='pt')

# %%
# with torch.no_grad():
#     # Convert PyTorch tensors to NumPy arrays
#     symptom_embedding = model(**symptom_tokens).last_hidden_state.mean(dim=1)
#     standard_symptom_embedding = model(**standard_symptom_tokens).last_hidden_state.mean(dim=1)

# # Convert PyTorch tensors to NumPy arrays    
# symptom_embedding_np = symptom_embedding.detach().numpy()
# standard_symptom_embedding_np = standard_symptom_embedding.detach().numpy()

# # Flatten the embeddings to 1D arrays
# flat_symptom_embedding = np.ravel(symptom_embedding_np)
# flat_standard_symptom_embedding = np.ravel(standard_symptom_embedding_np)

# # Calculate cosine similarity
# similarity_score = cosine_similarity([flat_symptom_embedding], [flat_standard_symptom_embedding])[0][0]
# print(f"Similarity Score: {similarity_score:.2f}")
